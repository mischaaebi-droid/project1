# %%
import requests
import pprint
import pandas as pd

url = "https://ws-old.parlament.ch/affairs/20263051"

headers = {
    "Accept": "application/json"
}

r = requests.get(url, headers=headers)

data = r.json()

# %%
print(data["shortId"])
print(data["affairType"]["name"])

print(data["author"]["councillor"]["name"])
print(data["author"]["councillor"]["id"])#id des einreichenden Parlamentariers
print(data["deposit"]["date"])#einreichungsdatum
titel = next(
    t["value"]
    for t in data["texts"]
    if t["type"]["name"] == "Titel des Geschäftes"
)

eingereichter_text = next(
    t["value"]
    for t in data["texts"]
    if t["type"]["name"] == "Eingereichter Text"
)

begruendung = next(
    t["value"]
    for t in data["texts"]
    if t["type"]["name"] == "Begründung"
)
print("---------------------------------")
print (titel)
print("---------------------------------")
print (eingereichter_text)
print("---------------------------------")
print (begruendung)
print("---------------------------------")
print("---------------------------------")
# Out:
# 26.3051
# Postulat
# Hurni Baptiste
# 4270
# 2026-03-04T00:00:00Z
# ---------------------------------
# Evaluation und Verbesserung der Entschädigungen der Opfer in der Schweiz
# ---------------------------------
# <p>Der Bundesrat wird beauftragt, einen Bericht zu erarbeiten, der die Entschädigung der Opfer in der Schweiz und insbesondere allfällige Mängel im System evaluiert. Die Evaluation soll auch Verbesserungslösungen umfassen, z.&nbsp;B. eine Stärkung des Opferhilfegesetzes und die Einrichtung eines Nationalen Garantiefonds, analog zum Fonds, der im Strassenverkehrsgesetz vorgesehen ist.</p>
# ---------------------------------
# <p>Die schreckliche Brandkatastrophe in Crans-Montana hat unvermittelt die Mängel im System zur Entschädigung der Opfer in der Schweiz ans Licht gebracht. Denn die ohnehin schon tragische Situation eines Opfers kann sich noch verschlimmern, wenn nur eine minimale Entschädigung ausgerichtet wird, während die finanzielle Zukunft des Opfers ernsthaft eingeschränkt ist. Wenn nämlich die Täterin oder der Täter keine Haftpflichtversicherung hat, die Versicherungssumme viel zu niedrig ist oder die abgeschlossene Versicherung den Schaden nicht deckt – namentlich bei vorsätzlichen Delikten – und wenn dann die Täterin oder der Täter nicht zahlungsfähig ist oder nicht ausfindig gemacht werden kann, bleibt den Opfern als einziger Schutz das Opferhilfegesetz. Verbesserungen in diesem Bereich sind umso dringlicher, als das Parlament für den Strassenverkehr ‒ und nur für diesen und keinen anderen Bereich ‒ einen Nationalen Garantiefonds ins Leben gerufen hat. Dies kann zu schwerwiegenden Ungerechtigkeiten führen und hat den Bundesrat veranlasst, dem Parlament eine «Lex Crans-Montana» vorzulegen. Auch aus den schlimmsten Katastrophen müssen Lehren gezogen werden. Deshalb wird der Bundesrat beauftragt, in einem Bericht verschiedene Lösungen zu prüfen, z.&nbsp;B. die Stärkung der Instrumente des Opferhilfegesetzes, die Ausdehnung des Geltungsbereichs des heutigen Nationalen Garantiefonds, die Schaffung eines neuen Garantiefonds nach dem Modell des Fonds im Strassenverkehrsrecht oder eine andere Lösung, die sich an der Lehre orientiert.&nbsp;</p>
# ---------------------------------
# ---------------------------------

# %% [raw]
# pprint.pprint(data)

# %%
print(data)
# Out:
# {'id': 20263051, 'updated': '2026-06-02T14:58:32Z', 'additionalIndexing': '52;24;1216', 'affairType': {'abbreviation': 'Po.', 'id': 6, 'name': 'Postulat'}, 'author': {'councillor': {'code': 3162, 'gender': 'm', 'id': 4270, 'name': 'Hurni Baptiste', 'officialDenomination': 'Hurni'}, 'faction': {'abbreviation': 'Fraktion S', 'code': 'S', 'id': 2, 'name': 'Sozialdemokratische Fraktion'}, 'type': 'author'}, 'deposit': {'council': {'abbreviation': 'SR', 'id': 2, 'name': 'Ständerat', 'type': 'S'}, 'date': '2026-03-04T00:00:00Z', 'legislativePeriod': 52, 'session': '5212'}, 'descriptors': [], 'drafts': [{'consultation': {'resolutions': [{'category': {'id': 3, 'name': 'Normal'}, 'council': {'abbreviation': 'SR', 'id': 2, 'name': 'Ständerat', 'type': 'S'}, 'date': '2026-06-02T00:00:00Z', 'text': 'Annahme', 'type': 20}]}, 'federalCouncilProposal': {'code': '+', 'date': '2026-05-20T00:00:00Z', 'text': 'Annahme'}, 'index': 0, 'links': [], 'preConsultations': [], 'references': [], 'relatedDepartments': [{'abbreviation': 'EJPD', 'id': 5, 'name': 'Justiz- und Polizeidepartement', 'leading': True}], 'states': [{'date': '/Date(1772578800000+0100)/', 'id': 202, 'name': 'Eingereicht'}, {'date': '/Date(1779228000000+0200)/', 'id': 203, 'name': 'Stellungnahme zum Vorstoss liegt vor'}, {'date': '/Date(1779746400000+0200)/', 'id': 207, 'name': 'In Ständerat geplant'}, {'date': '/Date(1780351200000+0200)/', 'id': 209, 'name': 'Überwiesen an den Bundesrat'}], 'texts': []}], 'language': 'de', 'priorityCouncils': [{'abbreviation': 'SR', 'id': 2, 'name': 'Ständerat', 'type': 'S', 'priority': 1}], 'relatedAffairs': [], 'roles': [{'councillor': {'code': 2632, 'gender': 'm', 'id': 1120, 'name': 'Sommaruga Carlo', 'officialDenomination': 'Sommaruga Carlo'}, 'type': 'cosign'}, {'councillor': {'code': 3175, 'gender': 'f', 'id': 4283, 'name': 'Roth Franziska', 'officialDenomination': 'Roth Franziska'}, 'type': 'cosign'}, {'councillor': {'code': 3194, 'gender': 'f', 'id': 4239, 'name': 'Herzog Eva', 'officialDenomination': 'Herzog Eva'}, 'type': 'cosign'}, {'councillor': {'code': 2513, 'gender': 'm', 'id': 491, 'name': 'Maillard Pierre-Yves', 'officialDenomination': 'Maillard Pierre-Yves'}, 'type': 'cosign'}, {'councillor': {'code': 3125, 'gender': 'f', 'id': 4224, 'name': 'Wasserfallen Flavia', 'officialDenomination': 'Wasserfallen Flavia'}, 'type': 'cosign'}, {'councillor': {'code': 3227, 'gender': 'f', 'id': 4332, 'name': 'Crevoisier Crelier Mathilde', 'officialDenomination': 'Crevoisier Crelier'}, 'type': 'cosign'}, {'councillor': {'code': 3152, 'gender': 'm', 'id': 4260, 'name': 'Fivaz Fabien', 'officialDenomination': 'Fivaz Fabien'}, 'type': 'cosign'}, {'councillor': {'code': 3162, 'gender': 'm', 'id': 4270, 'name': 'Hurni Baptiste', 'officialDenomination': 'Hurni'}, 'faction': {'abbreviation': 'Fraktion S', 'code': 'S', 'id': 2, 'name': 'Sozialdemokratische Fraktion'}, 'type': 'author'}], 'shortId': '26.3051', 'state': {'id': 209, 'name': 'Überwiesen an den Bundesrat', 'doneKey': '0', 'newKey': 0}, 'texts': [{'type': {'id': 6, 'name': 'Begründung'}, 'value': '<p>Die schreckliche Brandkatastrophe in Crans-Montana hat unvermittelt die Mängel im System zur Entschädigung der Opfer in der Schweiz ans Licht gebracht. Denn die ohnehin schon tragische Situation eines Opfers kann sich noch verschl
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\.venvs\lede\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 21
#      17         data = r.json()
#      18     else:
#      19         print(f"Nicht gefunden: 2023{number}")
#      20
# ---> 21     data = r.json()
#      22     demand_list.append(data)
#      23
#      24     with open("geschaefte.jsonl", "a", encoding="utf-8") as f:
#
# File ~\.venvs\lede\Lib\site-packages\requests\models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import json
import pandas as pd

rows = []

with open("geschaefte.jsonl", encoding="utf-8") as f:
    for line in f:
        rows.append(json.loads(line))

print(len(rows))
# Out:
# 4851

# %%
flat = []

for g in rows:

    if "councillor" not in g.get("author", {}):
        continue

    flat.append({"person_code": g["author"]["councillor"]["code"],"author": g["author"]["councillor"]["name"],"type": g["affairType"]["name"]})

df = pd.DataFrame(flat)

# %%
df_Int = (
    df[df["type"] == "Interpellation"]
    .groupby(["person_code", "author"])
    .size()
)

df_Post = (
    df[df["type"] == "Postulat"]
    .groupby(["person_code", "author"])
    .size()
)

df_Mot = (
    df[df["type"] == "Motion"]
    .groupby(["person_code", "author"])
    .size()
)

df_tot = (
    df.groupby(["person_code", "author"])
    .size()
)

# %%
df_stats = pd.DataFrame({
    "total": df_tot,
    "motionen": df_Mot,
    "postulate": df_Post,
    "interpellationen": df_Int
}).fillna(0)

# %%
df_stats = df_stats.reset_index()

# %%
df_stats.sort_values("total", ascending=False).head(20)
# Out:
#      index  person_code                          author  total  motionen  \
# 15      15         2752                  Quadri Lorenzo     44      18.0
# 90      90         3124                   Molina Fabian     30      11.0
# 129    129         3180              Schlatter Marionna     25       8.0
# 150    150         3207                  Marchesi Piero     22       9.0
# 118    118         3164  Klopfenstein Broggini Delphine     20       2.0
# 138    138         3190                Weichelt Manuela     20       5.0
# 52      52         3055                  Addor Jean-Luc     20       9.0
# 103    103         3145               Clivaz Christophe     20       2.0
# 203    203        10836                   Kolly Nicolas     19       8.0
# 162    162         3222                  Mahaim Raphaël     18       1.0
# 151    151         3208                    Storni Bruno     17       4.0
# 127    127         3178                 Ryser Franziska     17       4.0
# 221    221        11506                      Rumy Farah     16       4.0
# 173    173        10805                  Broulis Pascal     16       6.0
# 166    166         3228                   Meier Andreas     16       8.0
# 130    130         3181                 Schneider Meret     16       9.0
# 93      93         3130                      Egger Mike     16       4.0
# 107    107         3149           de Quattro Jacqueline     16       4.0
# 206    206        10840                      Pahud Yvan     16       4.0
# 199    199        10832                   Knutti Thomas     16       8.0
#
#      postulate  interpellationen
# 15         1.0              25.0
# 90         0.0              19.0
# 129        1.0              16.0
# 150        0.0              13.0
# 118        3.0              15.0
# 138        2.0              13.0
# 52         0.0              11.0
# 103        0.0              18.0
# 203        0.0              11.0
# 162        2.0              15.0
# 151        2.0              11.0
# 127        1.0              12.0
# 221        3.0               9.0
# 173        2.0               8.0
# 166        4.0               4.0
# 130        4.0               3.0
# 93         0.0              12.0
# 107        3.0               8.0
# 206        0.0              12.0
# 199        1.0               7.0

# %%
import json

liste = df_stats.to_dict(orient="records")

with open("parlamentarier_stats.json", "w", encoding="utf-8") as f:
    json.dump(liste, f, ensure_ascii=False, indent=2)
